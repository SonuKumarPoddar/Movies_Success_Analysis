# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
movies = pd.read_csv('../data/tmdb_5000_movies.csv')
credits = pd.read_csv('../data/tmdb_5000_credits.csv')

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\DELL\\movie_sucsess_analysis\\notebooks'

# %%
movies.shape
movies.info()
movies.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4803 non-null   object
#  2   homepage              1712 non-null   object
#  3   id                    4803 non-null   int64
#  4   keywords              4803 non-null   object
#  5   original_language     4803 non-null   object
#  6   original_title        4803 non-null   object
#  7   overview              4800 non-null   object
#  8   popularity            4803 non-null   float64
#  9   production_companies  4803 non-null   object
#  10  production_countries  4803 non-null   object
#  11  release_date          4802 non-null   object
#  12  revenue               4803 non-null   int64
#  13  runtime               4801 non-null   float64
#  14  spoken_languages      4803 non-null   object
# ...

# %%
credits.shape
# Out:
# (4803, 4)

# %%
credits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   movie_id  4803 non-null   int64
#  1   title     4803 non-null   object
#  2   cast      4803 non-null   object
#  3   crew      4803 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 150.2+ KB

# %%
credits.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# ...

# %%
#removing rows having 0 values in budget and revnue
movies = movies[movies['budget'] > 0]
movies = movies[movies['revenue'] > 0]

# %%
#changibng date format from ddmmyyyy to yyyymmdd for 

movies['release_date'] = pd.to_datetime(
    movies['release_date'],
    dayfirst=True,
    errors='coerce'
)

# %%
movies['release_date'].head()
# Out:
# 0   2009-12-10
# 1   2007-05-19
# 2   2015-10-26
# 3   2012-07-16
# 4   2012-03-07
# Name: release_date, dtype: datetime64[ns]

# %%
#creating new colom for profit

movies['profit'] = movies['revenue'] - movies['budget']

# %%
movies.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
#creating Return on Investment coloum 
movies['roi'] = movies['profit'] / movies['budget']

# %%
movies.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
#removing duplicates
movies.drop_duplicates(inplace=True)
credits.drop_duplicates(inplace=True)

# %%
movies.isnull().sum()
# Out:
# budget                     0
# genres                     0
# homepage                1882
# id                         0
# keywords                   0
# original_language          0
# original_title             0
# overview                   0
# popularity                 0
# production_companies       0
# production_countries       0
# release_date               0
# revenue                    0
# runtime                    0
# spoken_languages           0
# status                     0
# tagline                  245
# title                      0
# vote_average               0
# vote_count                 0
# profit                     0
# roi                        0
# dtype: int64

# %%
movies.drop(columns=['homepage', 'tagline'], inplace=True)

# %%
movies.head()
# Out:
#       budget                                             genres      id  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   19995
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...     285
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  206647
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...   49026
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...                en
#
#                              original_title  \
# 0                                    Avatar
# ...

# %%
movies.shape
# Out:
# (3229, 20)

# %%
movies = movies.dropna(subset=['release_date', 'genres'])

# %%
import ast

# %%
def extract_genres(genre_str):
    try:
        genres = ast.literal_eval(genre_str)
        return [g['name'] for g in genres]
    except:
        return []

# %%
movies['genre_list'] = movies['genres'].apply(extract_genres)

movies['primary_genre'] = movies['genre_list'].apply(
    lambda x: x[0] if len(x) > 0 else None
)

# %%
movies[['genres', 'genre_list', 'primary_genre']].head()
# Out:
#                                               genres  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                       genre_list primary_genre
# 0  [Action, Adventure, Fantasy, Science Fiction]        Action
# 1                   [Adventure, Fantasy, Action]     Adventure
# 2                     [Action, Adventure, Crime]        Action
# 3               [Action, Crime, Drama, Thriller]        Action
# 4           [Action, Adventure, Science Fiction]        Action

# %%
movies.shape
movies.describe()
# Out:
#              budget             id   popularity  \
# count  3.229000e+03    3229.000000  3229.000000
# mean   4.065444e+07   44780.705791    29.033689
# min    1.000000e+00       5.000000     0.019984
# 25%    1.050000e+07    4958.000000    10.446722
# 50%    2.500000e+07   11451.000000    20.410354
# 75%    5.500000e+07   45272.000000    37.335721
# max    3.800000e+08  417859.000000   875.581305
# std    4.439674e+07   74609.434723    36.165730
#
#                         release_date       revenue      runtime  vote_average  \
# count                           3229  3.229000e+03  3229.000000   3229.000000
# mean   2002-03-21 04:03:29.600495488  1.212430e+08   110.724373      6.309353
# min              1916-09-04 00:00:00  5.000000e+00    41.000000      0.000000
# 25%              1998-09-11 00:00:00  1.700000e+07    96.000000      5.800000
# 50%              2005-07-20 00:00:00  5.518472e+07   107.000000      6.300000
# ...

# %%
plt.figure()
plt.scatter(movies['budget'], movies['revenue'])
plt.xlabel('Budget')
plt.ylabel('Revenue')
plt.title('Budget vs Revenue')
plt.show()

# %%
plt.figure()
movies['profit'].hist(bins=50)
plt.xlabel('Profit')
plt.ylabel('Number of Movies')
plt.title('Profit Distribution')
plt.show()

# %%
plt.figure()
movies['roi'].hist(bins=50)
plt.xlabel('ROI')
plt.ylabel('Number of Movies')
plt.title('ROI Distribution')
plt.show()

# %%
movies['roi'].idxmax()
# Out:
# np.int64(4238)

# %%
movies
# Out:
#          budget                                             genres      id  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   19995
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...     285
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  206647
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...   49026
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   49529
# ...         ...                                                ...     ...
# 4773      27000                     [{"id": 35, "name": "Comedy"}]    2292
# 4788      12000  [{"id": 27, "name": "Horror"}, {"id": 35, "nam...     692
# 4792      20000  [{"id": 80, "name": "Crime"}, {"id": 27, "name...   36095
# 4796       7000  [{"id": 878, "name": "Science Fiction"}, {"id"...   14337
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...    9367
#
# ...

# %%
movies.loc[movies['roi'].idxmax()]
# Out:
# budget                                                                  1
# genres                  [{"id": 18, "name": "Drama"}, {"id": 35, "name...
# id                                                                   3082
# keywords                [{"id": 1382, "name": "factory"}, {"id": 1546,...
# original_language                                                      en
# original_title                                               Modern Times
# overview                The Tramp struggles to live in modern industri...
# popularity                                                       28.27648
# production_companies    [{"name": "United Artists", "id": 60}, {"name"...
# production_countries    [{"iso_3166_1": "US", "name": "United States o...
# release_date                                          1936-02-05 00:00:00
# revenue                                                           8500000
# runtime                                                              87.0
# ...

# %%
movies = movies[movies['budget'] >= 10000]

# %% [markdown]
# movies

# %%
movies
# Out:
#          budget                                             genres      id  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   19995
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...     285
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  206647
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...   49026
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   49529
# ...         ...                                                ...     ...
# 4772      31192  [{"id": 18, "name": "Drama"}, {"id": 28, "name...   42151
# 4773      27000                     [{"id": 35, "name": "Comedy"}]    2292
# 4788      12000  [{"id": 27, "name": "Horror"}, {"id": 35, "nam...     692
# 4792      20000  [{"id": 80, "name": "Crime"}, {"id": 27, "name...   36095
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...    9367
#
# ...

# %%
movies.loc[movies['budget'] <= 1, 'budget'] = np.nan
movies = movies.dropna(subset=['budget'])

# %%
movies['roi_clean'] = np.where(movies['budget'] <= 1, 
                               np.nan, 
                               movies['roi'])

# %%
plt.figure()
plt.hist(movies[movies['roi_clean'] < 10]['roi_clean'], bins=50)
plt.xlabel('ROI')
plt.ylabel('Number of Movies')
plt.title('Clean ROI Distribution (ROI < 10)')
plt.show()

# %%
genre_count = movies['primary_genre'].value_counts()

plt.figure()
genre_count.plot(kind='bar')
plt.xlabel('Genre')
plt.ylabel('Number of Movies')
plt.title('Number of Movies by Genre')
plt.show()

# %% [markdown]
# Drama and Comedy dominate in volume, while Action and Adventure have fewer but higher-budget films.

# %%
genre_revenue = movies.groupby('primary_genre')['revenue'].mean().sort_values(ascending=False)

plt.figure()
genre_revenue.plot(kind='bar')
plt.xlabel('Genre')
plt.ylabel('Average Revenue')
plt.title('Average Revenue by Genre')
plt.show()

# %% [markdown]
# Animation , Adventure and Family generate the highest average revenues.

# %%
genre_profit = movies.groupby('primary_genre')['profit'].sum().sort_values(ascending=False)

plt.figure()
genre_profit.plot(kind='bar')
plt.xlabel('Genre')
plt.ylabel('sum of Profit')
plt.title('Sum of Profit by Genre')
plt.show()

# %% [markdown]
# High-budget genres earn more profit but also carry higher risk.

# %%
genre_roi = movies.groupby('primary_genre')['roi_clean'].mean().sort_values(ascending=False)

plt.figure()
genre_roi.plot(kind='bar')
plt.xlabel('Genre')
plt.ylabel('Average ROI')
plt.title('Average ROI by Genre')
plt.show()

# %% [markdown]
# Horror and Documentary genres offer high ROI due to low budgets, while Action dominates total revenue.

# %%
df = movies.merge(
    credits,
    left_on='id',
    right_on='movie_id',
    how='inner'
)

# %%
df.shape
df.columns
# Out:
# Index(['budget', 'genres', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'title_x', 'vote_average', 'vote_count',
#        'profit', 'roi', 'genre_list', 'primary_genre', 'roi_clean', 'movie_id',
#        'title_y', 'cast', 'crew'],
#       dtype='object')

# %%
df.shape
# Out:
# (3214, 27)

# %%
df.drop(columns=['movie_id'], inplace=True)

# %%
df.rename(columns={'title_x': 'title'}, inplace=True)
df.drop(columns=['title_y'], inplace=True)

# %%
df[['title', 'crew']].head()
# Out:
#                                       title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...

# %%
df['director'] = df['crew'].apply(get_director)

# %%
def get_director(crew_text):
    try:
        crew = ast.literal_eval(crew_text)
        for member in crew:
            if member.get('job') == 'Director':
                return member.get('name')
    except:
        return None

# %%
df['director'] = df['crew'].apply(get_director)

# %%
df[['title', 'director']].head()
# Out:
#                                       title           director
# 0                                    Avatar      James Cameron
# 1  Pirates of the Caribbean: At World's End     Gore Verbinski
# 2                                   Spectre         Sam Mendes
# 3                     The Dark Knight Rises  Christopher Nolan
# 4                               John Carter     Andrew Stanton

# %%
df['director'].isnull().sum()
# Out:
# np.int64(2)

# %%
df = df.dropna(subset=['director'])

# %%
director_revenue = (
    df.groupby('director')['revenue']
    .mean()
    .sort_values(ascending=False)
)

director_revenue.head(10)
# Out:
# director
# Chris Buck          1.274219e+09
# Kyle Balda          1.156731e+09
# Lee Unkrich         1.066970e+09
# Joss Whedon         9.879437e+08
# Chris Renaud        8.759583e+08
# James Cameron       8.405099e+08
# Roger Allers        7.882418e+08
# Tim Miller          7.831130e+08
# Colin Trevorrow     7.587683e+08
# Robert Stromberg    7.585398e+08
# Name: revenue, dtype: float64

# %%
director_roi = (
    df.groupby('director')['roi']
    .mean()
    .sort_values(ascending=False)
)

director_roi.head(10)
# Out:
# director
# Oren Peli             12889.386667
# Daniel Myrick          4132.333333
# Morgan Spurlock         438.616585
# Travis Cluff            425.644100
# Al Silliman Jr.         269.000000
# John Waters             249.300796
# Chris Kentis            212.536780
# David Lynch             175.829118
# David Hand              156.498795
# Melvin Van Peebles      100.333333
# Name: roi, dtype: float64

# %%
director_counts = df['director'].value_counts()

valid_directors = director_counts[director_counts >= 3].index

director_roi_filtered = (
    df[df['director'].isin(valid_directors)]
    .groupby('director')['roi']
    .mean()
    .sort_values(ascending=False)
)

director_roi_filtered.head(10)
# Out:
# director
# David Lynch           175.829118
# David Hand            156.498795
# Tobe Hooper            93.145577
# Alex Kendrick          66.739388
# George A. Romero       55.260249
# George Lucas           53.328446
# George Miller          38.076975
# Victor Fleming         37.080266
# William Brent Bell     36.063001
# James Wan              31.084662
# Name: roi, dtype: float64

# %%
df.drop(columns=['roi'], inplace=True)

# %%
df.to_csv('final_movies_data.csv', index=False)

# %%
df.rename(columns={'roi_clean': 'roi'}, inplace=True)

# %%
def movie_verdict(roi):
    if roi < 0:
        return 'Flop'
    elif roi < 1:
        return 'Average'
    elif roi < 2:
        return 'Hit'
    elif roi < 3:
        return 'Super Hit'
    else:
        return 'Blockbuster'

# %%
df['movie_verdict'] = df['roi'].apply(movie_verdict)

# %%
df[['title', 'roi', 'movie_verdict']].head()
# Out:
#                                       title        roi movie_verdict
# 0                                    Avatar  10.763566   Blockbuster
# 1  Pirates of the Caribbean: At World's End   2.203333     Super Hit
# 2                                   Spectre   2.594590     Super Hit
# 3                     The Dark Knight Rises   3.339756   Blockbuster
# 4                               John Carter   0.092843       Average

# %% [markdown]
# I classified movies into success categories using ROI thresholds to align financial performance with business understanding.

# %%
df['movie_verdict'].value_counts()
# Out:
# movie_verdict
# Blockbuster    915
# Flop           783
# Average        628
# Hit            532
# Super Hit      354
# Name: count, dtype: int64

# %%
df['roi_percent'] = (df['profit'] / df['budget']) * 100

# %%
top_10_directors_roi = roi_by_director.sort_values(
    by='roi_percent', ascending=False
).head(10)

top_10_directors_roi
# Out:
#               director   roi_percent
# 990          Oren Peli  1.288939e+06
# 257      Daniel Myrick  4.132333e+05
# 293        David Lynch  7.033165e+04
# 668        John Waters  4.986016e+04
# 287         David Hand  4.694964e+04
# 943    Morgan Spurlock  4.386166e+04
# 1366      Travis Cluff  4.256441e+04
# 182       Chris Kentis  4.250736e+04
# 1334       Tobe Hooper  3.725823e+04
# 440   George A. Romero  2.763012e+04

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
plt.barh(top_10_directors['director'], top_10_directors['sum_roi'])
plt.xlabel('Sum of ROI (%)')
plt.ylabel('Director')
plt.title('Top 10 Directors by Sum of ROI (Min 5 Movies)')
plt.gca().invert_yaxis()
plt.show()

# %%
director_roi = director_roi.sort_values('avg_roi', ascending=False)

# %%
director_roi = director_roi[director_roi['movie_count'] >= 5]

# %%
director_roi = (
    df.groupby('director')
      .agg(
          avg_roi=('roi', 'mean'),
          movie_count=('title', 'count')
      )
      .reset_index()
)

# %%
top10 = director_roi.head(10)

plt.figure(figsize=(12, 6))
plt.barh(top10['director'], top10['avg_roi'])
plt.xlabel('Average ROI (%)')
plt.title('Top 10 Directors by ROI')
plt.gca().invert_yaxis()
plt.show()

# %%
df.to_excel('final_movies_data_clean.xlsx', index=False)
